# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    'train',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 10400 files belonging to 13 classes.

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 2600 files belonging to 13 classes.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import json

# Define the input shape for 64x64 image size
input_shape = (128, 128, 3)

# Create a Sequential model
cnn = tf.keras.models.Sequential()

# Add convolutional layers
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=input_shape))
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu'))  # Use 'same' padding here
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# Dropout and Flatten layers
cnn.add(tf.keras.layers.Dropout(0.25))
cnn.add(tf.keras.layers.Flatten())

# Dense layers
cnn.add(tf.keras.layers.Dense(units=1500, activation='relu'))
cnn.add(tf.keras.layers.Dropout(0.4))

# Output layer
cnn.add(tf.keras.layers.Dense(units=16, activation='softmax'))

# Compile the model with Adam optimizer
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
            loss='categorical_crossentropy',
            metrics=['accuracy'])

# Display model summary
cnn.summary()

# Training the model
training_history = cnn.fit(x=training_set, validation_data=validation_set, epochs=10)

# Training set accuracy
train_loss, train_acc = cnn.evaluate(training_set)
print('Training accuracy:', train_acc)

# Validation set accuracy
val_loss, val_acc = cnn.evaluate(validation_set)
print('Validation accuracy:', val_acc)

# Save the trained model
cnn.save('CNN_Rice_and_Jack_Fruit_Plant_Disease_Detection_model.keras')

# Save training history as JSON
with open('training_hist.json', 'w') as f:
    json.dump(training_history.history, f)

# Print keys of the training history dictionary
print(training_history.history.keys())

# Plot training and validation accuracy
epochs = range(1, len(training_history.history['accuracy']) + 1)
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, training_history.history['accuracy'], color='blue', label='Training Accuracy')
plt.plot(epochs, training_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('Model Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, training_history.history['loss'], color='blue', label='Training Loss')
plt.plot(epochs, training_history.history['val_loss'], color='orange', label='Validation Loss')
plt.xlabel('No. of Epochs')
plt.title('Model Loss')
plt.legend()

plt.show()

# Load validation set class names
class_name = validation_set.class_names

# Load test dataset
test_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=1,
    image_size=(128, 128),  # Adjusted to match the input shape
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)

# Predict classes on test set
y_pred = cnn.predict(test_set)
predicted_categories = tf.argmax(y_pred, axis=1).numpy()

true_categories = tf.concat([y for x, y in test_set], axis=0)
Y_true = tf.argmax(true_categories, axis=1).numpy()

# Display true and predicted categories
print('True categories:')
print(Y_true)
print('Predicted categories:')
print(predicted_categories)

# Generate confusion matrix
cm = confusion_matrix(Y_true, predicted_categories)

# Print precision, recall, f1-score
print(classification_report(Y_true, predicted_categories, target_names=class_name))

plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_name, yticklabels=class_name)

plt.xlabel('Predicted Class', fontsize=12)
plt.ylabel('Actual Class', fontsize=12)
plt.title('Confusion Matrix', fontsize=15)

# Save confusion matrix plot as PNG file
conf_matrix_plot_path = "./image/confusion_matrix_plot.png"
plt.savefig(conf_matrix_plot_path, dpi=300, bbox_inches='tight')

plt.show()
# Out:
# C:\Users\User\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 126, 126, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 63, 63, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 61, 61, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 30, 30, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 28, 28, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 14, 14, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 12, 12, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 6, 6, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 6, 6, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 4608)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1500)                │       6,913,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 1500)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │          24,016 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,649,740 (44.44 MB)
#  Trainable params: 11,649,740 (44.44 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 184s 456ms/step - accuracy: 0.2150 - loss: 2.3829 - val_accuracy: 0.5269 - val_loss: 1.4302
# Epoch 2/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 195s 488ms/step - accuracy: 0.5495 - loss: 1.3516 - val_accuracy: 0.7097 - val_loss: 0.8518
# Epoch 3/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 198s 494ms/step - accuracy: 0.7470 - loss: 0.7577 - val_accuracy: 0.8069 - val_loss: 0.5684
# Epoch 4/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 197s 493ms/step - accuracy: 0.8565 - loss: 0.4412 - val_accuracy: 0.8841 - val_loss: 0.3751
# Epoch 5/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 197s 492ms/step - accuracy: 0.9099 - loss: 0.2735 - val_accuracy: 0.8906 - val_loss: 0.3363
# Epoch 6/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 199s 499ms/step - accuracy: 0.9343 - loss: 0.2139 - val_accuracy: 0.9109 - val_loss: 0.3157
# Epoch 7/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 201s 501ms/step - accuracy: 0.9468 - loss: 0.1582 - val_accuracy: 0.9262 - val_loss: 0.2743
# Epoch 8/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 200s 500ms/step - accuracy: 0.9603 - loss: 0.1297 - val_accuracy: 0.9022 - val_loss: 0.3137
# Epoch 9/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 204s 509ms/step - accuracy: 0.9642 - loss: 0.1211 - val_accuracy: 0.9247 - val_loss: 0.2772
# Epoch 10/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 207s 517ms/step - accuracy: 0.9765 - loss: 0.0839 - val_accuracy: 0.9166 - val_loss: 0.3253
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 60s 151ms/step - accuracy: 0.9735 - loss: 0.0803
# Training accuracy: 0.9770312309265137
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 143ms/step - accuracy: 0.9176 - loss: 0.3595
# Validation accuracy: 0.9165624976158142
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# Found 3200 files belonging to 16 classes.
# 3200/3200 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step
# True categories:
# [ 0  0  0 ... 15 15 15]
# Predicted categories:
# [ 0  0  0 ... 15 15 15]
#                                                         precision    recall  f1-score   support
#
#                Potato Pest__Agrotis ipsilon (Hufnagel)       0.94      1.00      0.97       200
#               Potato Pest__Amrasca devastans (Distant)       1.00      0.99      0.99       200
#                     Potato Pest__Aphis gossypii Glover       0.95      1.00      0.98       200
#                Potato Pest__Bemisia tabaci (Gennadius)       0.92      1.00      0.96       200
#     Potato Pest__Brachytrypes portentosus Lichtenstein       0.99      1.00      1.00       200
# Potato Pest__Epilachna vigintioctopunctata (Fabricius)       1.00      1.00      1.00       200
#                   Potato Pest__Myzus persicae (Sulzer)       0.93      0.92      0.92       200
#          Potato Pest__Phthorimaea operculella (Zeller)       0.98      1.00      0.99       200
#                      Tomato pest__Bemisia argentifolii       0.98      0.83      0.90       200
#                      Tomato pest__Helicoverpa armigera       0.83      0.66      0.73       200
#                            Tomato pest__Myzus persicae       0.62      0.83      0.71       200
#                         Tomato pest__Spodoptera exigua       0.91      0.73      0.81       200
#                         Tomato pest__Spodoptera litura       0.80      0.91      0.85       200
#                       Tomato pest__Tetranychus urticae       0.95      0.82      0.88       200
#                              Tomato pest__Thrips palmi       0.97      1.00      0.98       200
#                     Tomato pest__Zeugodacus cucurbitae       0.99      0.98      0.99       200
#
#                                               accuracy                           0.92      3200
#                                              macro avg       0.92      0.92      0.92      3200
#                                           weighted avg       0.92      0.92      0.92      3200
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 145
#     143 # Save confusion matrix plot as PNG file
#     144 conf_matrix_plot_path = "./image/confusion_matrix_plot.png"
# --> 145 plt.savefig(conf_matrix_plot_path, dpi=300, bbox_inches='tight')
#     147 plt.show()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# -> 1228 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1229 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1230 return res
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\figure.py:3395, in Figure.savefig(self, fname, transparent, **kwargs)
#    3393     for ax in self.axes:
#    3394         _recursively_make_axes_transparent(stack, ax)
# -> 3395 self.canvas.print_figure(fname, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\backend_bases.py:2204, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2200 try:
#    2201     # _get_renderer may change the figure dpi (as vector formats
#    2202     # force the figure dpi to 72), so we need to set it again here.
#    2203     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2204         result = print_method(
#    2205             filename,
#    2206             facecolor=facecolor,
#    2207             edgecolor=edgecolor,
#    2208             orientation=orientation,
#    2209             bbox_inches_restore=_bbox_inches_restore,
#    2210             **kwargs)
#    2211 finally:
#    2212     if bbox_inches and restore_bbox:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\backend_bases.py:2054, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2050     optional_kws = {  # Passed by print_figure for other renderers.
#    2051         "dpi", "facecolor", "edgecolor", "orientation",
#    2052         "bbox_inches_restore"}
#    2053     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2054     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2055         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2056 else:  # Let third-parties do as they see fit.
#    2057     print_method = meth
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\backends\backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\backends\backend_agg.py:445, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     440 """
#     441 Draw the canvas, then save it using `.image.imsave` (to which
#     442 *pil_kwargs* and *metadata* are forwarded).
#     443 """
#     444 FigureCanvasAgg.draw(self)
# --> 445 mpl.image.imsave(
#     446     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\image.py:1676, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1674 pil_kwargs.setdefault("format", format)
#    1675 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1676 image.save(fname, **pil_kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\PIL\Image.py:2600, in Image.save(self, fp, format, **params)
#    2598         fp = builtins.open(filename, "r+b")
#    2599     else:
# -> 2600         fp = builtins.open(filename, "w+b")
#    2601 else:
#    2602     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\User\\Desktop\\Pest Detection\\image\\confusion_matrix_plot.png'

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    'train',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 10400 files belonging to 13 classes.

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 2600 files belonging to 13 classes.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import json

# Define the input shape for 64x64 image size
input_shape = (128, 128, 3)

# Create a Sequential model
cnn = tf.keras.models.Sequential()

# Add convolutional layers
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=input_shape))
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu'))  # Use 'same' padding here
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# Dropout and Flatten layers
cnn.add(tf.keras.layers.Dropout(0.25))
cnn.add(tf.keras.layers.Flatten())

# Dense layers
cnn.add(tf.keras.layers.Dense(units=1500, activation='relu'))
cnn.add(tf.keras.layers.Dropout(0.4))

# Output layer
cnn.add(tf.keras.layers.Dense(units=13, activation='softmax'))

# Compile the model with Adam optimizer
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
            loss='categorical_crossentropy',
            metrics=['accuracy'])

# Display model summary
cnn.summary()

# Training the model
training_history = cnn.fit(x=training_set, validation_data=validation_set, epochs=10)

# Training set accuracy
train_loss, train_acc = cnn.evaluate(training_set)
print('Training accuracy:', train_acc)

# Validation set accuracy
val_loss, val_acc = cnn.evaluate(validation_set)
print('Validation accuracy:', val_acc)

# Save the trained model
cnn.save('CNN_Rice_and_Jack_Fruit_Plant_Disease_Detection_model.keras')

# Save training history as JSON
with open('training_hist.json', 'w') as f:
    json.dump(training_history.history, f)

# Print keys of the training history dictionary
print(training_history.history.keys())

# Plot training and validation accuracy
epochs = range(1, len(training_history.history['accuracy']) + 1)
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, training_history.history['accuracy'], color='blue', label='Training Accuracy')
plt.plot(epochs, training_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('Model Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, training_history.history['loss'], color='blue', label='Training Loss')
plt.plot(epochs, training_history.history['val_loss'], color='orange', label='Validation Loss')
plt.xlabel('No. of Epochs')
plt.title('Model Loss')
plt.legend()

plt.show()

# Load validation set class names
class_name = validation_set.class_names

# Load test dataset
test_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=1,
    image_size=(128, 128),  # Adjusted to match the input shape
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)

# Predict classes on test set
y_pred = cnn.predict(test_set)
predicted_categories = tf.argmax(y_pred, axis=1).numpy()

true_categories = tf.concat([y for x, y in test_set], axis=0)
Y_true = tf.argmax(true_categories, axis=1).numpy()

# Display true and predicted categories
print('True categories:')
print(Y_true)
print('Predicted categories:')
print(predicted_categories)

# Generate confusion matrix
cm = confusion_matrix(Y_true, predicted_categories)

# Print precision, recall, f1-score
print(classification_report(Y_true, predicted_categories, target_names=class_name))

plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_name, yticklabels=class_name)

plt.xlabel('Predicted Class', fontsize=12)
plt.ylabel('Actual Class', fontsize=12)
plt.title('Confusion Matrix', fontsize=15)

# Save confusion matrix plot as PNG file
conf_matrix_plot_path = "./image/confusion_matrix_plot.png"
plt.savefig(conf_matrix_plot_path, dpi=300, bbox_inches='tight')

plt.show()
# Out:
# C:\Users\User\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_10 (Conv2D)                   │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 126, 126, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 63, 63, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 61, 61, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 30, 30, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_15 (Conv2D)                   │ (None, 28, 28, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_16 (Conv2D)                   │ (None, 14, 14, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_17 (Conv2D)                   │ (None, 12, 12, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 6, 6, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 6, 6, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 4608)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1500)                │       6,913,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 1500)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 13)                  │          19,513 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,645,237 (44.42 MB)
#  Trainable params: 11,645,237 (44.42 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 140s 426ms/step - accuracy: 0.2237 - loss: 2.3456 - val_accuracy: 0.5635 - val_loss: 1.2826
# Epoch 2/10
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 155s 477ms/step - accuracy: 0.6224 - loss: 1.0881 - val_accuracy: 0.8019 - val_loss: 0.6284
# Epoch 3/10
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 159s 488ms/step - accuracy: 0.8362 - loss: 0.4823 - val_accuracy: 0.9335 - val_loss: 0.2340
# Epoch 4/10
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 159s 489ms/step - accuracy: 0.9072 - loss: 0.3236 - val_accuracy: 0.9481 - val_loss: 0.1625
# Epoch 5/10
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 159s 491ms/step - accuracy: 0.9528 - loss: 0.1487 - val_accuracy: 0.9577 - val_loss: 0.1479
# Epoch 6/10
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 160s 491ms/step - accuracy: 0.9656 - loss: 0.1080 - val_accuracy: 0.9623 - val_loss: 0.1580
# Epoch 7/10
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 159s 489ms/step - accuracy: 0.9768 - loss: 0.0769 - val_accuracy: 0.9804 - val_loss: 0.0721
# Epoch 8/10
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 160s 492ms/step - accuracy: 0.9764 - loss: 0.0687 - val_accuracy: 0.9477 - val_loss: 0.1658
# Epoch 9/10
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 159s 489ms/step - accuracy: 0.9774 - loss: 0.0750 - val_accuracy: 0.9792 - val_loss: 0.0687
# Epoch 10/10
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 163s 502ms/step - accuracy: 0.9832 - loss: 0.0514 - val_accuracy: 0.9777 - val_loss: 0.0747
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 46s 140ms/step - accuracy: 0.9961 - loss: 0.0128
# Training accuracy: 0.995192289352417
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 138ms/step - accuracy: 0.9742 - loss: 0.0902
# Validation accuracy: 0.9776923060417175
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# Found 2600 files belonging to 13 classes.
# 2600/2600 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step
# True categories:
# [ 0  0  0 ... 12 12 12]
# Predicted categories:
# [ 0  0  0 ... 10  7 12]
#                                                         precision    recall  f1-score   support
#
#                Potato Pest__Agrotis ipsilon (Hufnagel)       0.97      1.00      0.99       200
#               Potato Pest__Amrasca devastans (Distant)       1.00      1.00      1.00       200
#                     Potato Pest__Aphis gossypii Glover       1.00      1.00      1.00       200
#                Potato Pest__Bemisia tabaci (Gennadius)       1.00      0.96      0.98       200
#     Potato Pest__Brachytrypes portentosus Lichtenstein       1.00      1.00      1.00       200
# Potato Pest__Epilachna vigintioctopunctata (Fabricius)       0.98      0.98      0.98       200
#                   Potato Pest__Myzus persicae (Sulzer)       0.99      0.99      0.99       200
#          Potato Pest__Phthorimaea operculella (Zeller)       0.97      1.00      0.98       200
#                      Tomato pest__Bemisia argentifolii       0.93      0.98      0.96       200
#                         Tomato pest__Spodoptera exigua       0.95      0.94      0.94       200
#                       Tomato pest__Tetranychus urticae       0.95      0.93      0.94       200
#                              Tomato pest__Thrips palmi       1.00      0.98      0.99       200
#                     Tomato pest__Zeugodacus cucurbitae       0.97      0.94      0.96       200
#
#                                               accuracy                           0.98      2600
#                                              macro avg       0.98      0.98      0.98      2600
#                                           weighted avg       0.98      0.98      0.98      2600

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import json

# Define the input shape for 64x64 image size
input_shape = (128, 128, 3)

# Create a Sequential model
cnn = tf.keras.models.Sequential()

# Add convolutional layers
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=input_shape))
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu'))  # Use 'same' padding here
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# Dropout and Flatten layers
cnn.add(tf.keras.layers.Dropout(0.25))
cnn.add(tf.keras.layers.Flatten())

# Dense layers
cnn.add(tf.keras.layers.Dense(units=1500, activation='relu'))
cnn.add(tf.keras.layers.Dropout(0.4))

# Output layer
cnn.add(tf.keras.layers.Dense(units=13, activation='softmax'))

# Compile the model with Adam optimizer
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
            loss='categorical_crossentropy',
            metrics=['accuracy'])

# Display model summary
cnn.summary()

# Training the model
training_history = cnn.fit(x=training_set, validation_data=validation_set, epochs=50)

# Training set accuracy
train_loss, train_acc = cnn.evaluate(training_set)
print('Training accuracy:', train_acc)

# Validation set accuracy
val_loss, val_acc = cnn.evaluate(validation_set)
print('Validation accuracy:', val_acc)

# Save the trained model
cnn.save('CNN_Rice_and_Jack_Fruit_Plant_Disease_Detection_model.keras')

# Save training history as JSON
with open('training_hist.json', 'w') as f:
    json.dump(training_history.history, f)

# Print keys of the training history dictionary
print(training_history.history.keys())

# Plot training and validation accuracy
epochs = range(1, len(training_history.history['accuracy']) + 1)
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, training_history.history['accuracy'], color='blue', label='Training Accuracy')
plt.plot(epochs, training_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('Model Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, training_history.history['loss'], color='blue', label='Training Loss')
plt.plot(epochs, training_history.history['val_loss'], color='orange', label='Validation Loss')
plt.xlabel('No. of Epochs')
plt.title('Model Loss')
plt.legend()

plt.show()

# Load validation set class names
class_name = validation_set.class_names

# Load test dataset
test_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=1,
    image_size=(128, 128),  # Adjusted to match the input shape
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)

# Predict classes on test set
y_pred = cnn.predict(test_set)
predicted_categories = tf.argmax(y_pred, axis=1).numpy()

true_categories = tf.concat([y for x, y in test_set], axis=0)
Y_true = tf.argmax(true_categories, axis=1).numpy()

# Display true and predicted categories
print('True categories:')
print(Y_true)
print('Predicted categories:')
print(predicted_categories)

# Generate confusion matrix
cm = confusion_matrix(Y_true, predicted_categories)

# Print precision, recall, f1-score
print(classification_report(Y_true, predicted_categories, target_names=class_name))

plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_name, yticklabels=class_name)

plt.xlabel('Predicted Class', fontsize=12)
plt.ylabel('Actual Class', fontsize=12)
plt.title('Confusion Matrix', fontsize=15)

# Save confusion matrix plot as PNG file
conf_matrix_plot_path = "./image/confusion_matrix_plot.png"
plt.savefig(conf_matrix_plot_path, dpi=300, bbox_inches='tight')

plt.show()
# Out:
# C:\Users\User\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_20 (Conv2D)                   │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 126, 126, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 63, 63, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 61, 61, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_24 (Conv2D)                   │ (None, 30, 30, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_25 (Conv2D)                   │ (None, 28, 28, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_26 (Conv2D)                   │ (None, 14, 14, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_27 (Conv2D)                   │ (None, 12, 12, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_28 (Conv2D)                   │ (None, 6, 6, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_29 (Conv2D)                   │ (None, 6, 6, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_14 (MaxPooling2D)      │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 4608)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1500)                │       6,913,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 1500)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 13)                  │          19,513 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,645,237 (44.42 MB)
#  Trainable params: 11,645,237 (44.42 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 152s 462ms/step - accuracy: 0.2088 - loss: 2.3713 - val_accuracy: 0.6000 - val_loss: 1.2014
# Epoch 2/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 158s 485ms/step - accuracy: 0.5933 - loss: 1.1587 - val_accuracy: 0.8104 - val_loss: 0.5356
# Epoch 3/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 164s 505ms/step - accuracy: 0.8273 - loss: 0.5203 - val_accuracy: 0.8985 - val_loss: 0.3174
# Epoch 4/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 163s 503ms/step - accuracy: 0.9236 - loss: 0.2480 - val_accuracy: 0.9531 - val_loss: 0.1413
# Epoch 5/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 159s 488ms/step - accuracy: 0.9537 - loss: 0.1427 - val_accuracy: 0.9681 - val_loss: 0.1426
# Epoch 6/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 155s 478ms/step - accuracy: 0.9735 - loss: 0.0783 - val_accuracy: 0.9662 - val_loss: 0.1407
# Epoch 7/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 157s 482ms/step - accuracy: 0.9617 - loss: 0.1262 - val_accuracy: 0.9585 - val_loss: 0.1664
# Epoch 8/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 156s 481ms/step - accuracy: 0.9734 - loss: 0.0882 - val_accuracy: 0.9800 - val_loss: 0.0769
# Epoch 9/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 155s 478ms/step - accuracy: 0.9854 - loss: 0.0465 - val_accuracy: 0.9804 - val_loss: 0.1285
# Epoch 10/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 155s 475ms/step - accuracy: 0.9802 - loss: 0.1038 - val_accuracy: 0.9804 - val_loss: 0.1053
# Epoch 11/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 155s 477ms/step - accuracy: 0.9847 - loss: 0.0538 - val_accuracy: 0.9777 - val_loss: 0.0942
# Epoch 12/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 475ms/step - accuracy: 0.9863 - loss: 0.0434 - val_accuracy: 0.9581 - val_loss: 0.1586
# Epoch 13/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 474ms/step - accuracy: 0.9889 - loss: 0.0402 - val_accuracy: 0.9796 - val_loss: 0.0865
# Epoch 14/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 475ms/step - accuracy: 0.9845 - loss: 0.0574 - val_accuracy: 0.9796 - val_loss: 0.1134
# Epoch 15/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 474ms/step - accuracy: 0.9949 - loss: 0.0188 - val_accuracy: 0.9781 - val_loss: 0.1060
# Epoch 16/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 475ms/step - accuracy: 0.9900 - loss: 0.0366 - val_accuracy: 0.9704 - val_loss: 0.1266
# Epoch 17/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 155s 476ms/step - accuracy: 0.9888 - loss: 0.0404 - val_accuracy: 0.9558 - val_loss: 0.2161
# Epoch 18/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 474ms/step - accuracy: 0.9830 - loss: 0.0575 - val_accuracy: 0.9781 - val_loss: 0.1132
# Epoch 19/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 475ms/step - accuracy: 0.9886 - loss: 0.0388 - val_accuracy: 0.9735 - val_loss: 0.1050
# Epoch 20/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 155s 477ms/step - accuracy: 0.9950 - loss: 0.0161 - val_accuracy: 0.9842 - val_loss: 0.0823
# Epoch 21/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 474ms/step - accuracy: 0.9909 - loss: 0.0331 - val_accuracy: 0.9719 - val_loss: 0.1399
# Epoch 22/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 475ms/step - accuracy: 0.9841 - loss: 0.0477 - val_accuracy: 0.9812 - val_loss: 0.1044
# Epoch 23/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 475ms/step - accuracy: 0.9947 - loss: 0.0163 - val_accuracy: 0.9677 - val_loss: 0.1413
# Epoch 24/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 156s 481ms/step - accuracy: 0.9885 - loss: 0.0395 - val_accuracy: 0.9708 - val_loss: 0.1279
# Epoch 25/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 155s 477ms/step - accuracy: 0.9896 - loss: 0.0353 - val_accuracy: 0.9831 - val_loss: 0.0548
# Epoch 26/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 156s 480ms/step - accuracy: 0.9941 - loss: 0.0169 - val_accuracy: 0.9858 - val_loss: 0.0633
# Epoch 27/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 474ms/step - accuracy: 0.9973 - loss: 0.0093 - val_accuracy: 0.9804 - val_loss: 0.0950
# Epoch 28/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 155s 477ms/step - accuracy: 0.9944 - loss: 0.0217 - val_accuracy: 0.9812 - val_loss: 0.1125
# Epoch 29/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 474ms/step - accuracy: 0.9946 - loss: 0.0232 - val_accuracy: 0.9738 - val_loss: 0.0999
# Epoch 30/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 475ms/step - accuracy: 0.9914 - loss: 0.0263 - val_accuracy: 0.9808 - val_loss: 0.0873
# Epoch 31/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 155s 476ms/step - accuracy: 0.9899 - loss: 0.0318 - val_accuracy: 0.9850 - val_loss: 0.0878
# Epoch 32/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 155s 477ms/step - accuracy: 0.9961 - loss: 0.0161 - val_accuracy: 0.9865 - val_loss: 0.0828
# Epoch 33/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 474ms/step - accuracy: 0.9936 - loss: 0.0254 - val_accuracy: 0.9804 - val_loss: 0.0908
# Epoch 34/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 473ms/step - accuracy: 0.9951 - loss: 0.0157 - val_accuracy: 0.9846 - val_loss: 0.0927
# Epoch 35/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 160s 492ms/step - accuracy: 0.9989 - loss: 0.0031 - val_accuracy: 0.9873 - val_loss: 0.0868
# Epoch 36/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 155s 476ms/step - accuracy: 0.9984 - loss: 0.0030 - val_accuracy: 0.9792 - val_loss: 0.1484
# Epoch 37/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 473ms/step - accuracy: 0.9908 - loss: 0.0302 - val_accuracy: 0.9746 - val_loss: 0.1160
# Epoch 38/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 474ms/step - accuracy: 0.9920 - loss: 0.0284 - val_accuracy: 0.9862 - val_loss: 0.0656
# Epoch 39/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 474ms/step - accuracy: 0.9990 - loss: 0.0045 - val_accuracy: 0.9854 - val_loss: 0.0713
# Epoch 40/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 473ms/step - accuracy: 0.9985 - loss: 0.0051 - val_accuracy: 0.9804 - val_loss: 0.1030
# Epoch 41/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 474ms/step - accuracy: 0.9936 - loss: 0.0227 - val_accuracy: 0.9692 - val_loss: 0.1689
# Epoch 42/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 474ms/step - accuracy: 0.9791 - loss: 0.0699 - val_accuracy: 0.9858 - val_loss: 0.0742
# Epoch 43/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 474ms/step - accuracy: 0.9992 - loss: 0.0041 - val_accuracy: 0.9815 - val_loss: 0.0917
# Epoch 44/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 155s 476ms/step - accuracy: 0.9954 - loss: 0.0221 - val_accuracy: 0.9835 - val_loss: 0.0971
# Epoch 45/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 473ms/step - accuracy: 0.9990 - loss: 0.0047 - val_accuracy: 0.9792 - val_loss: 0.0969
# Epoch 46/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 474ms/step - accuracy: 0.9966 - loss: 0.0119 - val_accuracy: 0.9765 - val_loss: 0.1024
# Epoch 47/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 474ms/step - accuracy: 0.9904 - loss: 0.0506 - val_accuracy: 0.9781 - val_loss: 0.1123
# Epoch 48/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 156s 480ms/step - accuracy: 0.9907 - loss: 0.0300 - val_accuracy: 0.9854 - val_loss: 0.0881
# Epoch 49/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 155s 476ms/step - accuracy: 0.9993 - loss: 0.0021 - val_accuracy: 0.9862 - val_loss: 0.0748
# Epoch 50/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 154s 474ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9850 - val_loss: 0.0846
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 44s 134ms/step - accuracy: 0.9998 - loss: 6.4671e-04
# Training accuracy: 0.9998077154159546
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 133ms/step - accuracy: 0.9783 - loss: 0.1191
# Validation accuracy: 0.9850000143051147
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# Found 2600 files belonging to 13 classes.
# 2600/2600 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step
# True categories:
# [ 0  0  0 ... 12 12 12]
# Predicted categories:
# [ 0  0  0 ... 12 12 12]
#                                                         precision    recall  f1-score   support
#
#                Potato Pest__Agrotis ipsilon (Hufnagel)       0.98      1.00      0.99       200
#               Potato Pest__Amrasca devastans (Distant)       0.98      1.00      0.99       200
#                     Potato Pest__Aphis gossypii Glover       0.97      1.00      0.99       200
#                Potato Pest__Bemisia tabaci (Gennadius)       0.99      1.00      1.00       200
#     Potato Pest__Brachytrypes portentosus Lichtenstein       1.00      1.00      1.00       200
# Potato Pest__Epilachna vigintioctopunctata (Fabricius)       0.99      1.00      1.00       200
#                   Potato Pest__Myzus persicae (Sulzer)       0.99      1.00      0.99       200
#          Potato Pest__Phthorimaea operculella (Zeller)       1.00      1.00      1.00       200
#                      Tomato pest__Bemisia argentifolii       0.97      0.96      0.97       200
#                         Tomato pest__Spodoptera exigua       0.99      0.91      0.95       200
#                       Tomato pest__Tetranychus urticae       0.97      0.95      0.96       200
#                              Tomato pest__Thrips palmi       0.99      1.00      1.00       200
#                     Tomato pest__Zeugodacus cucurbitae       0.99      0.97      0.98       200
#
#                                               accuracy                           0.98      2600
#                                              macro avg       0.99      0.98      0.98      2600
#                                           weighted avg       0.99      0.98      0.98      2600

# %%
# Generate confusion matrix
cm = confusion_matrix(Y_true, predicted_categories)

# Print precision, recall, f1-score
print(classification_report(Y_true, predicted_categories, target_names=class_name))

plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_name, yticklabels=class_name)

plt.xlabel('Predicted Class', fontsize=12)
plt.ylabel('Actual Class', fontsize=12)
plt.title('Custom CNN Confusion Matrix', fontsize=15)

# Save confusion matrix plot as PNG file
conf_matrix_plot_path = "./image/confusion_matrix_plot.png"
plt.savefig(conf_matrix_plot_path, dpi=300, bbox_inches='tight')

plt.show()
# Out:
#                                                         precision    recall  f1-score   support
#
#                Potato Pest__Agrotis ipsilon (Hufnagel)       0.98      1.00      0.99       200
#               Potato Pest__Amrasca devastans (Distant)       0.98      1.00      0.99       200
#                     Potato Pest__Aphis gossypii Glover       0.97      1.00      0.99       200
#                Potato Pest__Bemisia tabaci (Gennadius)       0.99      1.00      1.00       200
#     Potato Pest__Brachytrypes portentosus Lichtenstein       1.00      1.00      1.00       200
# Potato Pest__Epilachna vigintioctopunctata (Fabricius)       0.99      1.00      1.00       200
#                   Potato Pest__Myzus persicae (Sulzer)       0.99      1.00      0.99       200
#          Potato Pest__Phthorimaea operculella (Zeller)       1.00      1.00      1.00       200
#                      Tomato pest__Bemisia argentifolii       0.97      0.96      0.97       200
#                         Tomato pest__Spodoptera exigua       0.99      0.91      0.95       200
#                       Tomato pest__Tetranychus urticae       0.97      0.95      0.96       200
#                              Tomato pest__Thrips palmi       0.99      1.00      1.00       200
#                     Tomato pest__Zeugodacus cucurbitae       0.99      0.97      0.98       200
#
#                                               accuracy                           0.98      2600
#                                              macro avg       0.99      0.98      0.98      2600
#                                           weighted avg       0.99      0.98      0.98      2600

# %%
# Plot training and validation accuracy
epochs = range(1, len(training_history.history['accuracy']) + 1)
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, training_history.history['accuracy'], color='blue', label='Training Accuracy')
plt.plot(epochs, training_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('Custom CNN Model Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, training_history.history['loss'], color='blue', label='Training Loss')
plt.plot(epochs, training_history.history['val_loss'], color='orange', label='Validation Loss')
plt.xlabel('No. of Epochs')
plt.title('Custom CNN Model Loss')
plt.legend()

plt.show()
