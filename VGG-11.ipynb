# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    'train',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(32, 32),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 10400 files belonging to 13 classes.

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(32, 32),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 2600 files belonging to 13 classes.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import json

# Define the input shape for 64x64 image size
input_shape = (64, 64, 3)

# Load the VGG16 model with ImageNet weights, excluding the top layers
vgg_base = tf.keras.applications.VGG16(
    include_top=False,  # Exclude the fully connected layer at the top
    weights='imagenet',  # Use ImageNet weights
    input_shape=input_shape,  # Ensure input shape is set
    pooling='avg'  # Optionally use global average pooling instead of flattening
)

# Freeze the base model (do not train these layers)
vgg_base.trainable = False

# Create a Sequential model
cnn = tf.keras.models.Sequential()

# Add the VGG16 base model
cnn.add(vgg_base)

# Add fully connected layers after the VGG16 base
cnn.add(tf.keras.layers.Flatten())  # Flatten the 3D output to 1D for dense layers
cnn.add(tf.keras.layers.Dense(units=1500, activation='relu'))
cnn.add(tf.keras.layers.Dropout(0.4))

# Output layer for 15 classes (adjust based on your dataset)
cnn.add(tf.keras.layers.Dense(units=13, activation='softmax'))

# Compile the model
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
            loss='categorical_crossentropy',
            metrics=['accuracy'])

# Display model summary to check layers and parameters
cnn.summary()

# Training the model
training_history = cnn.fit(x=training_set, validation_data=validation_set, epochs=50)

# Training set accuracy
train_loss, train_acc = cnn.evaluate(training_set)
print('Training accuracy:', train_acc)

# Validation set accuracy
val_loss, val_acc = cnn.evaluate(validation_set)
print('Validation accuracy:', val_acc)

# Save the trained model
cnn.save('VGG16_Pest_Detection_model.keras')

# Save training history as JSON
with open('training_hist.json', 'w') as f:
    json.dump(training_history.history, f)

# Print keys of the training history dictionary
print(training_history.history.keys())

# Plot training and validation accuracy
epochs = range(1, len(training_history.history['accuracy']) + 1)
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, training_history.history['accuracy'], color='blue', label='Training Accuracy')
plt.plot(epochs, training_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('Model Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, training_history.history['loss'], color='blue', label='Training Loss')
plt.plot(epochs, training_history.history['val_loss'], color='orange', label='Validation Loss')
plt.xlabel('No. of Epochs')
plt.title('Model Loss')
plt.legend()

plt.show()

# Load validation set class names
class_name = validation_set.class_names

# Load test dataset
test_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=1,
    image_size=(64, 64),  # Adjusted to match the input shape
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)

# Predict classes on test set
y_pred = cnn.predict(test_set)
predicted_categories = tf.argmax(y_pred, axis=1).numpy()

true_categories = tf.concat([y for x, y in test_set], axis=0)
Y_true = tf.argmax(true_categories, axis=1).numpy()

# Display true and predicted categories
print('True categories:')
print(Y_true)
print('Predicted categories:')
print(predicted_categories)

# Generate confusion matrix
cm = confusion_matrix(Y_true, predicted_categories)

# Print precision, recall, f1-score
print(classification_report(Y_true, predicted_categories, target_names=class_name))

plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_name, yticklabels=class_name)

plt.xlabel('Predicted Class', fontsize=12)
plt.ylabel('Actual Class', fontsize=12)
plt.title('Confusion Matrix', fontsize=15)

# Save confusion matrix plot as PNG file
conf_matrix_plot_path = "./image/confusion_matrix_plot.png"
plt.savefig(conf_matrix_plot_path, dpi=300, bbox_inches='tight')

plt.show()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ ?                           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 14,714,688 (56.13 MB)
# Epoch 1/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 66s 200ms/step - accuracy: 0.3381 - loss: 7.2806 - val_accuracy: 0.8954 - val_loss: 0.3991
# Epoch 2/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 73s 224ms/step - accuracy: 0.7632 - loss: 1.2576 - val_accuracy: 0.9538 - val_loss: 0.1316
# Epoch 3/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.8740 - loss: 0.5299 - val_accuracy: 0.9808 - val_loss: 0.0674
# Epoch 4/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9221 - loss: 0.2862 - val_accuracy: 0.9904 - val_loss: 0.0354
# Epoch 5/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 233ms/step - accuracy: 0.9485 - loss: 0.1745 - val_accuracy: 0.9931 - val_loss: 0.0178
# Epoch 6/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9672 - loss: 0.1219 - val_accuracy: 0.9919 - val_loss: 0.0185
# Epoch 7/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 78s 239ms/step - accuracy: 0.9746 - loss: 0.0785 - val_accuracy: 0.9973 - val_loss: 0.0097
# Epoch 8/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9815 - loss: 0.0576 - val_accuracy: 0.9962 - val_loss: 0.0101
# Epoch 9/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 233ms/step - accuracy: 0.9869 - loss: 0.0406 - val_accuracy: 0.9988 - val_loss: 0.0050
# Epoch 10/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9869 - loss: 0.0433 - val_accuracy: 0.9988 - val_loss: 0.0029
# Epoch 11/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 77s 236ms/step - accuracy: 0.9904 - loss: 0.0263 - val_accuracy: 0.9977 - val_loss: 0.0059
# Epoch 12/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9902 - loss: 0.0291 - val_accuracy: 0.9992 - val_loss: 0.0030
# Epoch 13/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9948 - loss: 0.0161 - val_accuracy: 0.9992 - val_loss: 0.0024
# Epoch 14/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 77s 236ms/step - accuracy: 0.9934 - loss: 0.0195 - val_accuracy: 0.9985 - val_loss: 0.0042
# Epoch 15/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 235ms/step - accuracy: 0.9959 - loss: 0.0117 - val_accuracy: 0.9973 - val_loss: 0.0094
# Epoch 16/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 233ms/step - accuracy: 0.9959 - loss: 0.0132 - val_accuracy: 0.9985 - val_loss: 0.0035
# Epoch 17/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 233ms/step - accuracy: 0.9963 - loss: 0.0130 - val_accuracy: 0.9992 - val_loss: 0.0020
# Epoch 18/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 233ms/step - accuracy: 0.9940 - loss: 0.0178 - val_accuracy: 0.9988 - val_loss: 0.0029
# Epoch 19/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 235ms/step - accuracy: 0.9971 - loss: 0.0104 - val_accuracy: 0.9992 - val_loss: 0.0027
# Epoch 20/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9972 - loss: 0.0070 - val_accuracy: 0.9992 - val_loss: 0.0032
# Epoch 21/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 233ms/step - accuracy: 0.9963 - loss: 0.0094 - val_accuracy: 0.9985 - val_loss: 0.0031
# Epoch 22/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9978 - loss: 0.0063 - val_accuracy: 0.9992 - val_loss: 0.0027
# Epoch 23/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 233ms/step - accuracy: 0.9982 - loss: 0.0051 - val_accuracy: 0.9973 - val_loss: 0.0059
# Epoch 24/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 233ms/step - accuracy: 0.9983 - loss: 0.0054 - val_accuracy: 0.9992 - val_loss: 0.0034
# Epoch 25/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 235ms/step - accuracy: 0.9980 - loss: 0.0070 - val_accuracy: 0.9992 - val_loss: 0.0023
# Epoch 26/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9976 - loss: 0.0069 - val_accuracy: 0.9985 - val_loss: 0.0025
# Epoch 27/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9990 - loss: 0.0042 - val_accuracy: 0.9996 - val_loss: 9.6866e-04
# Epoch 28/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9980 - loss: 0.0073 - val_accuracy: 0.9996 - val_loss: 0.0015
# Epoch 29/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 233ms/step - accuracy: 0.9991 - loss: 0.0026 - val_accuracy: 0.9992 - val_loss: 0.0025
# Epoch 30/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 235ms/step - accuracy: 0.9991 - loss: 0.0041 - val_accuracy: 0.9996 - val_loss: 0.0012
# Epoch 31/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 235ms/step - accuracy: 0.9990 - loss: 0.0036 - val_accuracy: 0.9996 - val_loss: 0.0010
# Epoch 32/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9987 - loss: 0.0038 - val_accuracy: 0.9985 - val_loss: 0.0045
# Epoch 33/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9985 - loss: 0.0044 - val_accuracy: 0.9992 - val_loss: 0.0015
# Epoch 34/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9987 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 5.9038e-04
# Epoch 35/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9980 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 2.4578e-04
# Epoch 36/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 235ms/step - accuracy: 0.9983 - loss: 0.0059 - val_accuracy: 0.9996 - val_loss: 9.7793e-04
# Epoch 37/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 235ms/step - accuracy: 0.9993 - loss: 0.0016 - val_accuracy: 0.9996 - val_loss: 0.0011
# Epoch 38/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 77s 236ms/step - accuracy: 0.9999 - loss: 9.6131e-04 - val_accuracy: 0.9988 - val_loss: 0.0021
# Epoch 39/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 235ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 5.3678e-04
# Epoch 40/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 235ms/step - accuracy: 0.9985 - loss: 0.0062 - val_accuracy: 0.9996 - val_loss: 0.0018
# Epoch 41/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 235ms/step - accuracy: 0.9993 - loss: 0.0018 - val_accuracy: 0.9992 - val_loss: 0.0026
# Epoch 42/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 77s 236ms/step - accuracy: 0.9988 - loss: 0.0040 - val_accuracy: 0.9996 - val_loss: 0.0010
# Epoch 43/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 235ms/step - accuracy: 0.9981 - loss: 0.0040 - val_accuracy: 0.9992 - val_loss: 0.0016
# Epoch 44/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 235ms/step - accuracy: 0.9990 - loss: 0.0018 - val_accuracy: 0.9992 - val_loss: 0.0021
# Epoch 45/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 233ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9996 - val_loss: 0.0014
# Epoch 46/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9997 - loss: 6.7351e-04 - val_accuracy: 0.9996 - val_loss: 0.0015
# Epoch 47/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9996 - loss: 0.0012 - val_accuracy: 0.9988 - val_loss: 0.0022
# Epoch 48/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 234ms/step - accuracy: 0.9981 - loss: 0.0056 - val_accuracy: 0.9988 - val_loss: 0.0021
# Epoch 49/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 235ms/step - accuracy: 0.9999 - loss: 7.4968e-04 - val_accuracy: 0.9992 - val_loss: 0.0024
# Epoch 50/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 76s 233ms/step - accuracy: 0.9993 - loss: 0.0016 - val_accuracy: 0.9996 - val_loss: 0.0012
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 61s 188ms/step - accuracy: 1.0000 - loss: 4.7360e-06
# Training accuracy: 1.0
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 15s 185ms/step - accuracy: 0.9999 - loss: 5.1696e-04
# Validation accuracy: 0.9996153712272644
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# Found 2600 files belonging to 13 classes.
# 2600/2600 ━━━━━━━━━━━━━━━━━━━━ 34s 13ms/step
# True categories:
# [ 0  0  0 ... 12 12 12]
# Predicted categories:
# [ 0  0  0 ... 12 12 12]
#                                                         precision    recall  f1-score   support
#
#                Potato Pest__Agrotis ipsilon (Hufnagel)       1.00      1.00      1.00       200
#               Potato Pest__Amrasca devastans (Distant)       1.00      1.00      1.00       200
#                     Potato Pest__Aphis gossypii Glover       1.00      1.00      1.00       200
#                Potato Pest__Bemisia tabaci (Gennadius)       1.00      1.00      1.00       200
#     Potato Pest__Brachytrypes portentosus Lichtenstein       1.00      1.00      1.00       200
# Potato Pest__Epilachna vigintioctopunctata (Fabricius)       1.00      1.00      1.00       200
#                   Potato Pest__Myzus persicae (Sulzer)       1.00      1.00      1.00       200
#          Potato Pest__Phthorimaea operculella (Zeller)       1.00      1.00      1.00       200
#                      Tomato pest__Bemisia argentifolii       1.00      0.99      1.00       200
#                         Tomato pest__Spodoptera exigua       1.00      1.00      1.00       200
#                       Tomato pest__Tetranychus urticae       1.00      1.00      1.00       200
#                              Tomato pest__Thrips palmi       1.00      1.00      1.00       200
#                     Tomato pest__Zeugodacus cucurbitae       1.00      1.00      1.00       200
#
#                                               accuracy                           1.00      2600
#                                              macro avg       1.00      1.00      1.00      2600
#                                           weighted avg       1.00      1.00      1.00      2600

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import json

# Define the input shape for 64x64 image size
input_shape = (32, 32, 3)

# Load the VGG16 model with ImageNet weights, excluding the top layers
vgg_base = tf.keras.applications.VGG16(
    include_top=False,  # Exclude the fully connected layer at the top
    weights='imagenet',  # Use ImageNet weights
    input_shape=input_shape,  # Ensure input shape is set
    pooling='avg'  # Optionally use global average pooling instead of flattening
)

# Freeze the base model (do not train these layers)
vgg_base.trainable = False

# Create a Sequential model
cnn = tf.keras.models.Sequential()

# Add the VGG16 base model
cnn.add(vgg_base)

# Add fully connected layers after the VGG16 base
cnn.add(tf.keras.layers.Flatten())  # Flatten the 3D output to 1D for dense layers
cnn.add(tf.keras.layers.Dense(units=1500, activation='relu'))
cnn.add(tf.keras.layers.Dropout(0.4))

# Output layer for 15 classes (adjust based on your dataset)
cnn.add(tf.keras.layers.Dense(units=13, activation='softmax'))

# Compile the model
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
            loss='categorical_crossentropy',
            metrics=['accuracy'])

# Display model summary to check layers and parameters
cnn.summary()

# Training the model
training_history = cnn.fit(x=training_set, validation_data=validation_set, epochs=50)

# Training set accuracy
train_loss, train_acc = cnn.evaluate(training_set)
print('Training accuracy:', train_acc)

# Validation set accuracy
val_loss, val_acc = cnn.evaluate(validation_set)
print('Validation accuracy:', val_acc)

# Save the trained model
cnn.save('VGG16_Pest_Detection_model.keras')

# Save training history as JSON
with open('training_hist.json', 'w') as f:
    json.dump(training_history.history, f)

# Print keys of the training history dictionary
print(training_history.history.keys())

# Plot training and validation accuracy
epochs = range(1, len(training_history.history['accuracy']) + 1)
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, training_history.history['accuracy'], color='blue', label='Training Accuracy')
plt.plot(epochs, training_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('Model Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, training_history.history['loss'], color='blue', label='Training Loss')
plt.plot(epochs, training_history.history['val_loss'], color='orange', label='Validation Loss')
plt.xlabel('No. of Epochs')
plt.title('Model Loss')
plt.legend()

plt.show()

# Load validation set class names
class_name = validation_set.class_names

# Load test dataset
test_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=1,
    image_size=(32, 32),  # Adjusted to match the input shape
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)

# Predict classes on test set
y_pred = cnn.predict(test_set)
predicted_categories = tf.argmax(y_pred, axis=1).numpy()

true_categories = tf.concat([y for x, y in test_set], axis=0)
Y_true = tf.argmax(true_categories, axis=1).numpy()

# Display true and predicted categories
print('True categories:')
print(Y_true)
print('Predicted categories:')
print(predicted_categories)

# Generate confusion matrix
cm = confusion_matrix(Y_true, predicted_categories)

# Print precision, recall, f1-score
print(classification_report(Y_true, predicted_categories, target_names=class_name))

plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_name, yticklabels=class_name)

plt.xlabel('Predicted Class', fontsize=12)
plt.ylabel('Actual Class', fontsize=12)
plt.title('Confusion Matrix', fontsize=15)

# Save confusion matrix plot as PNG file
conf_matrix_plot_path = "./image/confusion_matrix_plot.png"
plt.savefig(conf_matrix_plot_path, dpi=300, bbox_inches='tight')

plt.show()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ ?                           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 14,714,688 (56.13 MB)
# Epoch 1/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 19s 55ms/step - accuracy: 0.2716 - loss: 12.8332 - val_accuracy: 0.8112 - val_loss: 1.0902
# Epoch 2/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 18s 54ms/step - accuracy: 0.6677 - loss: 2.7634 - val_accuracy: 0.9096 - val_loss: 0.4236
# Epoch 3/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 17s 53ms/step - accuracy: 0.7995 - loss: 1.2457 - val_accuracy: 0.9585 - val_loss: 0.1869
# Epoch 4/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 17s 54ms/step - accuracy: 0.8647 - loss: 0.6971 - val_accuracy: 0.9669 - val_loss: 0.1371
# Epoch 5/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 18s 57ms/step - accuracy: 0.9060 - loss: 0.4218 - val_accuracy: 0.9769 - val_loss: 0.0869
# Epoch 6/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9295 - loss: 0.2982 - val_accuracy: 0.9850 - val_loss: 0.0763
# Epoch 7/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 21s 64ms/step - accuracy: 0.9501 - loss: 0.1851 - val_accuracy: 0.9892 - val_loss: 0.0495
# Epoch 8/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 22s 68ms/step - accuracy: 0.9604 - loss: 0.1536 - val_accuracy: 0.9908 - val_loss: 0.0438
# Epoch 9/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 23s 70ms/step - accuracy: 0.9692 - loss: 0.1065 - val_accuracy: 0.9919 - val_loss: 0.0422
# Epoch 10/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 23s 71ms/step - accuracy: 0.9761 - loss: 0.0789 - val_accuracy: 0.9912 - val_loss: 0.0384
# Epoch 11/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 23s 71ms/step - accuracy: 0.9796 - loss: 0.0726 - val_accuracy: 0.9885 - val_loss: 0.0420
# Epoch 12/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 24s 72ms/step - accuracy: 0.9787 - loss: 0.0700 - val_accuracy: 0.9915 - val_loss: 0.0315
# Epoch 13/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 24s 74ms/step - accuracy: 0.9839 - loss: 0.0533 - val_accuracy: 0.9919 - val_loss: 0.0354
# Epoch 14/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 24s 74ms/step - accuracy: 0.9891 - loss: 0.0387 - val_accuracy: 0.9896 - val_loss: 0.0264
# Epoch 15/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 24s 75ms/step - accuracy: 0.9914 - loss: 0.0282 - val_accuracy: 0.9915 - val_loss: 0.0313
# Epoch 16/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 24s 75ms/step - accuracy: 0.9921 - loss: 0.0276 - val_accuracy: 0.9927 - val_loss: 0.0283
# Epoch 17/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 76ms/step - accuracy: 0.9920 - loss: 0.0276 - val_accuracy: 0.9946 - val_loss: 0.0169
# Epoch 18/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 24s 75ms/step - accuracy: 0.9918 - loss: 0.0218 - val_accuracy: 0.9958 - val_loss: 0.0203
# Epoch 19/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 75ms/step - accuracy: 0.9919 - loss: 0.0298 - val_accuracy: 0.9931 - val_loss: 0.0306
# Epoch 20/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 76ms/step - accuracy: 0.9893 - loss: 0.0353 - val_accuracy: 0.9946 - val_loss: 0.0335
# Epoch 21/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 76ms/step - accuracy: 0.9947 - loss: 0.0201 - val_accuracy: 0.9954 - val_loss: 0.0282
# Epoch 22/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 29s 88ms/step - accuracy: 0.9953 - loss: 0.0123 - val_accuracy: 0.9942 - val_loss: 0.0220
# Epoch 23/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 29s 88ms/step - accuracy: 0.9949 - loss: 0.0167 - val_accuracy: 0.9931 - val_loss: 0.0322
# Epoch 24/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 24s 75ms/step - accuracy: 0.9957 - loss: 0.0225 - val_accuracy: 0.9938 - val_loss: 0.0305
# Epoch 25/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 76ms/step - accuracy: 0.9952 - loss: 0.0224 - val_accuracy: 0.9942 - val_loss: 0.0254
# Epoch 26/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 75ms/step - accuracy: 0.9947 - loss: 0.0165 - val_accuracy: 0.9950 - val_loss: 0.0257
# Epoch 27/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 76ms/step - accuracy: 0.9957 - loss: 0.0138 - val_accuracy: 0.9935 - val_loss: 0.0332
# Epoch 28/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 75ms/step - accuracy: 0.9973 - loss: 0.0095 - val_accuracy: 0.9938 - val_loss: 0.0382
# Epoch 29/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 76ms/step - accuracy: 0.9959 - loss: 0.0135 - val_accuracy: 0.9958 - val_loss: 0.0283
# Epoch 30/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.9946 - loss: 0.0165 - val_accuracy: 0.9950 - val_loss: 0.0275
# Epoch 31/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.9978 - loss: 0.0078 - val_accuracy: 0.9942 - val_loss: 0.0364
# Epoch 32/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 76ms/step - accuracy: 0.9971 - loss: 0.0078 - val_accuracy: 0.9938 - val_loss: 0.0361
# Epoch 33/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 76ms/step - accuracy: 0.9962 - loss: 0.0140 - val_accuracy: 0.9942 - val_loss: 0.0369
# Epoch 34/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 26s 80ms/step - accuracy: 0.9978 - loss: 0.0089 - val_accuracy: 0.9950 - val_loss: 0.0345
# Epoch 35/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.9970 - loss: 0.0081 - val_accuracy: 0.9938 - val_loss: 0.0388
# Epoch 36/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.9983 - loss: 0.0061 - val_accuracy: 0.9946 - val_loss: 0.0365
# Epoch 37/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.9977 - loss: 0.0095 - val_accuracy: 0.9931 - val_loss: 0.0399
# Epoch 38/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 78ms/step - accuracy: 0.9986 - loss: 0.0096 - val_accuracy: 0.9969 - val_loss: 0.0241
# Epoch 39/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.9976 - loss: 0.0089 - val_accuracy: 0.9954 - val_loss: 0.0329
# Epoch 40/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.9983 - loss: 0.0050 - val_accuracy: 0.9965 - val_loss: 0.0266
# Epoch 41/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.9979 - loss: 0.0144 - val_accuracy: 0.9942 - val_loss: 0.0344
# Epoch 42/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 78ms/step - accuracy: 0.9977 - loss: 0.0069 - val_accuracy: 0.9942 - val_loss: 0.0349
# Epoch 43/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 26s 80ms/step - accuracy: 0.9979 - loss: 0.0105 - val_accuracy: 0.9958 - val_loss: 0.0213
# Epoch 44/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 26s 80ms/step - accuracy: 0.9986 - loss: 0.0046 - val_accuracy: 0.9954 - val_loss: 0.0250
# Epoch 45/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 26s 81ms/step - accuracy: 0.9983 - loss: 0.0063 - val_accuracy: 0.9965 - val_loss: 0.0239
# Epoch 46/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 78ms/step - accuracy: 0.9984 - loss: 0.0071 - val_accuracy: 0.9962 - val_loss: 0.0297
# Epoch 47/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 78ms/step - accuracy: 0.9993 - loss: 0.0023 - val_accuracy: 0.9962 - val_loss: 0.0225
# Epoch 48/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 78ms/step - accuracy: 0.9993 - loss: 0.0034 - val_accuracy: 0.9946 - val_loss: 0.0279
# Epoch 49/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 26s 79ms/step - accuracy: 0.9991 - loss: 0.0033 - val_accuracy: 0.9962 - val_loss: 0.0259
# Epoch 50/50
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 25s 76ms/step - accuracy: 0.9986 - loss: 0.0061 - val_accuracy: 0.9954 - val_loss: 0.0231
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9991 - loss: 0.0014
# Training accuracy: 0.9993269443511963
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.9960 - loss: 0.0148
# Validation accuracy: 0.9953846335411072
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# Found 2600 files belonging to 13 classes.
# 2600/2600 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step
# True categories:
# [ 0  0  0 ... 12 12 12]
# Predicted categories:
# [ 0  0  0 ... 12  0 12]
#                                                         precision    recall  f1-score   support
#
#                Potato Pest__Agrotis ipsilon (Hufnagel)       0.99      1.00      0.99       200
#               Potato Pest__Amrasca devastans (Distant)       1.00      0.99      0.99       200
#                     Potato Pest__Aphis gossypii Glover       1.00      1.00      1.00       200
#                Potato Pest__Bemisia tabaci (Gennadius)       1.00      1.00      1.00       200
#     Potato Pest__Brachytrypes portentosus Lichtenstein       1.00      1.00      1.00       200
# Potato Pest__Epilachna vigintioctopunctata (Fabricius)       1.00      1.00      1.00       200
#                   Potato Pest__Myzus persicae (Sulzer)       1.00      1.00      1.00       200
#          Potato Pest__Phthorimaea operculella (Zeller)       1.00      1.00      1.00       200
#                      Tomato pest__Bemisia argentifolii       0.99      0.97      0.98       200
#                         Tomato pest__Spodoptera exigua       0.99      0.99      0.99       200
#                       Tomato pest__Tetranychus urticae       0.98      0.99      0.99       200
#                              Tomato pest__Thrips palmi       1.00      1.00      1.00       200
#                     Tomato pest__Zeugodacus cucurbitae       0.99      0.99      0.99       200
#
#                                               accuracy                           1.00      2600
#                                              macro avg       1.00      1.00      1.00      2600
#                                           weighted avg       1.00      1.00      1.00      2600

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import json

# Define the input shape for 32x32 image size
input_shape = (32, 32, 3)

# Create a custom VGG11 model
def VGG11(input_shape, num_classes):
    model = tf.keras.Sequential([
        # Block 1
        tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu', input_shape=input_shape),
        tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2)),
        
        # Block 2
        tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2)),
        
        # Block 3
        tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2)),
        
        # Block 4
        tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2)),
        
        # Block 5
        tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2)),

        # Dense layers
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(4096, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(4096, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])
    return model

# Instantiate the model
cnn = VGG11(input_shape=input_shape, num_classes=13)

# Compile the model
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
            loss='categorical_crossentropy',
            metrics=['accuracy'])

# Display model summary to check layers and parameters
cnn.summary()

# Assume training_set and validation_set are predefined datasets
# Example usage might require loading your data into these variables
# Here is a placeholder for dataset loading which you need to define based on your application
# training_set = # your code to load training data
# validation_set = # your code to load validation data

# Training the model
training_history = cnn.fit(x=training_set, validation_data=validation_set, epochs=30)

# Training set accuracy
train_loss, train_acc = cnn.evaluate(training_set)
print('Training accuracy:', train_acc)

# Validation set accuracy
val_loss, val_acc = cnn.evaluate(validation_set)
print('Validation accuracy:', val_acc)

# Save the trained model
cnn.save('VGG11_Pest_Detection_model.keras')

# Save training history as JSON
with open('training_hist.json', 'w') as f:
    json.dump(training_history.history, f)

# Print keys of the training history dictionary
print(training_history.history.keys())

# Plot training and validation accuracy
epochs = range(1, len(training_history.history['accuracy']) + 1)
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, training_history.history['accuracy'], color='blue', label='Training Accuracy')
plt.plot(epochs, training_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('Model Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, training_history.history['loss'], color='blue', label='Training Loss')
plt.plot(epochs, training_history.history['val_loss'], color='orange', label='Validation Loss')
plt.xlabel('No. of Epochs')
plt.title('Model Loss')
plt.legend()

plt.show()

# Load validation set class names
class_name = validation_set.class_names

# Load test dataset
test_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=1,
    image_size=(32, 32),
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)

# Predict classes on test set
y_pred = cnn.predict(test_set)
predicted_categories = tf.argmax(y_pred, axis=1).numpy()

true_categories = tf.concat([y for x, y in test_set], axis=0)
Y_true = tf.argmax(true_categories, axis=1).numpy()

# Display true and predicted categories
print('True categories:')
print(Y_true)
print('Predicted categories:')
print(predicted_categories)

# Generate confusion matrix
cm = confusion_matrix(Y_true, predicted_categories)

# Print precision, recall, f1-score
print(classification_report(Y_true, predicted_categories, target_names=class_name))

plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_name, yticklabels=class_name)

plt.xlabel('Predicted Class', fontsize=12)
plt.ylabel('Actual Class', fontsize=12)
plt.title('Confusion Matrix', fontsize=15)

# Save confusion matrix plot as PNG file
conf_matrix_plot_path = "./image/confusion_matrix_plot.png"
plt.savefig(conf_matrix_plot_path, dpi=300, bbox_inches='tight')

plt.show()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_16 (Conv2D)                   │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_17 (Conv2D)                   │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_20 (Conv2D)                   │ (None, 4, 4, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 4, 4, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 2, 2, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 2, 2, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 2, 2, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_14 (MaxPooling2D)      │ (None, 1, 1, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_6 (Flatten)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 4096)                │       2,101,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 4096)                │      16,781,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 13)                  │          53,261 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 28,156,301 (107.41 MB)
#  Trainable params: 28,156,301 (107.41 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 70s 209ms/step - accuracy: 0.1771 - loss: 2.3563 - val_accuracy: 0.5388 - val_loss: 1.2882
# Epoch 2/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 71s 217ms/step - accuracy: 0.6318 - loss: 1.0479 - val_accuracy: 0.8192 - val_loss: 0.5132
# Epoch 3/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 72s 220ms/step - accuracy: 0.8641 - loss: 0.3968 - val_accuracy: 0.9092 - val_loss: 0.3042
# Epoch 4/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 73s 223ms/step - accuracy: 0.9343 - loss: 0.1912 - val_accuracy: 0.9473 - val_loss: 0.1793
# Epoch 5/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 73s 226ms/step - accuracy: 0.9640 - loss: 0.1067 - val_accuracy: 0.9235 - val_loss: 0.2643
# Epoch 6/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 73s 224ms/step - accuracy: 0.9690 - loss: 0.1020 - val_accuracy: 0.9388 - val_loss: 0.2204
# Epoch 7/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 73s 224ms/step - accuracy: 0.9780 - loss: 0.0756 - val_accuracy: 0.9423 - val_loss: 0.2232
# Epoch 8/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 226ms/step - accuracy: 0.9752 - loss: 0.0771 - val_accuracy: 0.9462 - val_loss: 0.2172
# Epoch 9/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 73s 225ms/step - accuracy: 0.9826 - loss: 0.0570 - val_accuracy: 0.9712 - val_loss: 0.1062
# Epoch 10/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 73s 225ms/step - accuracy: 0.9829 - loss: 0.0611 - val_accuracy: 0.9669 - val_loss: 0.1235
# Epoch 11/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 226ms/step - accuracy: 0.9895 - loss: 0.0336 - val_accuracy: 0.9727 - val_loss: 0.1253
# Epoch 12/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 227ms/step - accuracy: 0.9921 - loss: 0.0233 - val_accuracy: 0.9750 - val_loss: 0.0839
# Epoch 13/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 73s 226ms/step - accuracy: 0.9898 - loss: 0.0339 - val_accuracy: 0.9538 - val_loss: 0.1641
# Epoch 14/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 227ms/step - accuracy: 0.9882 - loss: 0.0399 - val_accuracy: 0.9588 - val_loss: 0.1414
# Epoch 15/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 229ms/step - accuracy: 0.9858 - loss: 0.0425 - val_accuracy: 0.9400 - val_loss: 0.2261
# Epoch 16/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 75s 230ms/step - accuracy: 0.9810 - loss: 0.0675 - val_accuracy: 0.9635 - val_loss: 0.1686
# Epoch 17/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 227ms/step - accuracy: 0.9854 - loss: 0.0540 - val_accuracy: 0.9754 - val_loss: 0.1125
# Epoch 18/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 227ms/step - accuracy: 0.9928 - loss: 0.0302 - val_accuracy: 0.9696 - val_loss: 0.1139
# Epoch 19/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 226ms/step - accuracy: 0.9918 - loss: 0.0258 - val_accuracy: 0.9623 - val_loss: 0.1423
# Epoch 20/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 228ms/step - accuracy: 0.9937 - loss: 0.0206 - val_accuracy: 0.9738 - val_loss: 0.0973
# Epoch 21/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 73s 226ms/step - accuracy: 0.9897 - loss: 0.0323 - val_accuracy: 0.9608 - val_loss: 0.1375
# Epoch 22/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 226ms/step - accuracy: 0.9891 - loss: 0.0448 - val_accuracy: 0.9627 - val_loss: 0.1434
# Epoch 23/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 226ms/step - accuracy: 0.9923 - loss: 0.0286 - val_accuracy: 0.9731 - val_loss: 0.1300
# Epoch 24/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 226ms/step - accuracy: 0.9898 - loss: 0.0420 - val_accuracy: 0.9758 - val_loss: 0.0977
# Epoch 25/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 227ms/step - accuracy: 0.9980 - loss: 0.0062 - val_accuracy: 0.9746 - val_loss: 0.1126
# Epoch 26/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 227ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.9785 - val_loss: 0.1015
# Epoch 27/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 227ms/step - accuracy: 0.9995 - loss: 8.2479e-04 - val_accuracy: 0.9796 - val_loss: 0.1049
# Epoch 28/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 227ms/step - accuracy: 1.0000 - loss: 3.2594e-04 - val_accuracy: 0.9800 - val_loss: 0.1087
# Epoch 29/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 227ms/step - accuracy: 1.0000 - loss: 2.0988e-05 - val_accuracy: 0.9800 - val_loss: 0.1108
# Epoch 30/30
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 228ms/step - accuracy: 1.0000 - loss: 1.3946e-05 - val_accuracy: 0.9800 - val_loss: 0.1128
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 1.0000 - loss: 5.7366e-06
# Training accuracy: 1.0
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9806 - loss: 0.1034
# Validation accuracy: 0.9800000190734863
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# Found 2600 files belonging to 13 classes.
# 2600/2600 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step
# True categories:
# [ 0  0  0 ... 12 12 12]
# Predicted categories:
# [ 0  0  0 ... 12 12 12]
#                                                         precision    recall  f1-score   support
#
#                Potato Pest__Agrotis ipsilon (Hufnagel)       0.97      0.98      0.98       200
#               Potato Pest__Amrasca devastans (Distant)       0.98      1.00      0.99       200
#                     Potato Pest__Aphis gossypii Glover       1.00      1.00      1.00       200
#                Potato Pest__Bemisia tabaci (Gennadius)       1.00      1.00      1.00       200
#     Potato Pest__Brachytrypes portentosus Lichtenstein       1.00      1.00      1.00       200
# Potato Pest__Epilachna vigintioctopunctata (Fabricius)       0.99      1.00      1.00       200
#                   Potato Pest__Myzus persicae (Sulzer)       0.99      1.00      1.00       200
#          Potato Pest__Phthorimaea operculella (Zeller)       1.00      1.00      1.00       200
#                      Tomato pest__Bemisia argentifolii       0.93      0.96      0.95       200
#                         Tomato pest__Spodoptera exigua       0.95      0.92      0.93       200
#                       Tomato pest__Tetranychus urticae       0.96      0.92      0.94       200
#                              Tomato pest__Thrips palmi       0.99      0.98      0.99       200
#                     Tomato pest__Zeugodacus cucurbitae       0.98      0.98      0.98       200
#
#                                               accuracy                           0.98      2600
#                                              macro avg       0.98      0.98      0.98      2600
#                                           weighted avg       0.98      0.98      0.98      2600

# %%
# Generate confusion matrix
cm = confusion_matrix(Y_true, predicted_categories)

# Print precision, recall, f1-score
print(classification_report(Y_true, predicted_categories, target_names=class_name))

plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_name, yticklabels=class_name)

plt.xlabel('Predicted Class', fontsize=12)
plt.ylabel('Actual Class', fontsize=12)
plt.title('VGG-11 Confusion Matrix', fontsize=15)

# Save confusion matrix plot as PNG file
conf_matrix_plot_path = "./image/confusion_matrix_plot.png"
plt.savefig(conf_matrix_plot_path, dpi=300, bbox_inches='tight')

plt.show()
# Out:
#                                                         precision    recall  f1-score   support
#
#                Potato Pest__Agrotis ipsilon (Hufnagel)       0.97      0.98      0.98       200
#               Potato Pest__Amrasca devastans (Distant)       0.98      1.00      0.99       200
#                     Potato Pest__Aphis gossypii Glover       1.00      1.00      1.00       200
#                Potato Pest__Bemisia tabaci (Gennadius)       1.00      1.00      1.00       200
#     Potato Pest__Brachytrypes portentosus Lichtenstein       1.00      1.00      1.00       200
# Potato Pest__Epilachna vigintioctopunctata (Fabricius)       0.99      1.00      1.00       200
#                   Potato Pest__Myzus persicae (Sulzer)       0.99      1.00      1.00       200
#          Potato Pest__Phthorimaea operculella (Zeller)       1.00      1.00      1.00       200
#                      Tomato pest__Bemisia argentifolii       0.93      0.96      0.95       200
#                         Tomato pest__Spodoptera exigua       0.95      0.92      0.93       200
#                       Tomato pest__Tetranychus urticae       0.96      0.92      0.94       200
#                              Tomato pest__Thrips palmi       0.99      0.98      0.99       200
#                     Tomato pest__Zeugodacus cucurbitae       0.98      0.98      0.98       200
#
#                                               accuracy                           0.98      2600
#                                              macro avg       0.98      0.98      0.98      2600
#                                           weighted avg       0.98      0.98      0.98      2600

# %%
# Plot training and validation accuracy
epochs = range(1, len(training_history.history['accuracy']) + 1)
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, training_history.history['accuracy'], color='blue', label='Training Accuracy')
plt.plot(epochs, training_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('VGG-11 Model Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, training_history.history['loss'], color='blue', label='Training Loss')
plt.plot(epochs, training_history.history['val_loss'], color='orange', label='Validation Loss')
plt.xlabel('No. of Epochs')
plt.title('VGG-11 Model Loss')
plt.legend()

plt.show()
